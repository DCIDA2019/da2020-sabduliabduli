# %%
# %pylab
# %matplotlib inline

import numpy as np
import pandas as pd
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

#Función que cuenta el número de incidencias en determinado rango en la base
#de datos.
def verificador(inferior, superior):
    contador = 0
    
    for i in range(len(sueldo_neto)):
        if sueldo_neto[i] >= inferior and sueldo_neto[i] <= superior:
            contador = contador + 1
    
    return(contador)

#Extracting data from .xls files:
data = pd.read_excel('tabulador_pe2019.xls', header = 9)
data = data.drop('TIPO', axis = 1)

nivel = data['NIVEL'].values
sueldo_neto = data['SUELDO MENSUAL NETO'].values

#Graficar histograma.
fig = plt.figure()
n, bins, patches = plt.hist(sueldo_neto, bins=20)
plt.title('Histograma de Sueldos Mensuales Netos')
plt.xlabel('Sueldo Mensual ($ MXN)')
plt.ylabel('Número de tipo de Empleos')
plt.show()

contador = 0


#Verificar número
print(verificador(0, 60000))
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib
# 64
